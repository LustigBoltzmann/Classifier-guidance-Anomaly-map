# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.datasets import make_s_curve, make_swiss_roll
import torch
import torch.nn as nn
from tqdm import tqdm
import numpy as np
import matplotlib.pyplot as plt
from scipy.fft import fft, fftfreq
import math

# %%
from google.colab import drive

drive.mount('/content/drive')

# %cd /content/drive/MyDrive
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive

# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive

# %%
import scipy.io as scio
from sklearn.model_selection import train_test_split
import pandas as pd
dict_ = scio.loadmat('AE_Diffusion/AE_data_ims/N2_data_C3_.mat')
data_ = dict_['data_c3_']
def normalize(data):
    data_ = (data-np.min(data))/(np.max(data)-np.min(data))
    return data_
#data_h = np.random.randn(1000,4,1024)
data_h = np.random.randn(1000,4096)
# data_1 = np.random.randn(4920,4,1024)
data_1 = np.random.randn(4920,4096)
ii = 0
for i in range(4920):
  data_1[i,:] = normalize(data_[i,:])
    # print(ii)
data_h = data_1[0:1000,:]
data_tva = data_1

# %%
# import scipy.io as scio
# from sklearn.model_selection import train_test_split
# import pandas as pd
# dict_ = scio.loadmat('AE_Diffusion/AE_data_ims/N2_data_C3_.mat')
# # dict_ = scio.loadmat('AE_Diffusion/AE_data_ims/data_3.mat')
# data_ = dict_['data_c3_']
# def normalize(data):
#     data_ = (data-np.min(data))/(np.max(data)-np.min(data))
#     return data_
# data_h = np.random.randn(1000,4096)
# data_1 = np.random.randn(4920,4096)
# ii = 0
# for i in range(4920):
#   data_1[i,:] = normalize(data_[i,0:4096])
#     # print(ii)
# data_h = data_1[0:1000,:]
# data_tva = data_1

# %%
# data_b = data_1[4880:4900,:]
# data_tv = np.concatenate((data_h, data_b),axis = 0)
# # data_test  = data_1[1000:-1,:,:]
# yh = np.zeros(1000)
# yu = np.ones(20)
# y_ = np.concatenate((yh,yu))
# data_tr,data_va,y_1,y_v = train_test_split(data_tv, y_, test_size=0.2, random_state=42)

# batch_size = 16 #考虑到样本总数仅为1000个,batch_size设定为64个
# # dataset放到dataloader中
# dataset_tensor = torch.utils.data.TensorDataset(torch.tensor(data_tr,dtype=torch.float32).cuda(),torch.tensor(y_1,dtype = torch.float32).cuda())
# #dataloader_1 = torch.utils.data.DataLoader(torch.tensor(data_tr,dtype=torch.float32).cuda(), batch_size=batch_size, shuffle=True)
# dataloader_1 = torch.utils.data.DataLoader(dataset_tensor,batch_size=batch_size, shuffle=True)

# %%
import scipy.io as scio
from sklearn.model_selection import train_test_split
import pandas as pd
# dict_ = scio.loadmat('AE_Diffusion/AE_data_ims/N2_data_C3_.mat')
dict_ = scio.loadmat('AE_Diffusion/AE_data_ims/data_3.mat')
data_ = dict_['data_1']
def normalize(data):
    data_ = (data-np.min(data))/(np.max(data)-np.min(data))
    return data_
data_h = np.random.randn(1000,4096)
data_1 = np.random.randn(6307,4096)
ii = 0
for i in range(6307):
  data_1[i,:] = normalize(data_[i,0:4096])
    # print(ii)
data_h = data_1[0:1000,:]

# %%
data_b = data_1[6277:6297,:]
data_tv = np.concatenate((data_h, data_b),axis = 0)
# data_test  = data_1[1000:-1,:,:]
yh = np.zeros(1000)
yu = np.ones(20)
y_ = np.concatenate((yh,yu))
data_tr,data_va,y_1,y_v = train_test_split(data_tv, y_, test_size=0.2, random_state=42)

batch_size = 16 #考虑到样本总数仅为1000个,batch_size设定为64个
# dataset放到dataloader中
dataset_tensor = torch.utils.data.TensorDataset(torch.tensor(data_tr,dtype=torch.float32).cuda(),torch.tensor(y_1,dtype = torch.float32).cuda())
#dataloader_1 = torch.utils.data.DataLoader(torch.tensor(data_tr,dtype=torch.float32).cuda(), batch_size=batch_size, shuffle=True)
dataloader_1 = torch.utils.data.DataLoader(dataset_tensor,batch_size=batch_size, shuffle=True)

# %%
import argparse
import csv
import numpy as np
from sklearn.model_selection import train_test_split
import torch
from sklearn.metrics import roc_auc_score, average_precision_score
import random
import os

torch.manual_seed(42)
torch.cuda.manual_seed_all(42)
np.random.seed(42)
random.seed(42)


# def dataLoading(dataset):
#   x = []
#   labels = []
#   dim = 0
#   path = 'dataset/' + dataset + '.csv'
#   with open(path, 'r') as f:
#     csv_reader = csv.reader(f)
#     for i in csv_reader:
#       if dataset == 'spambase_normalization':
#         dim = len(i) - 1
#       else:
#         dim = len(i) - 2
#       x.append(i[0:dim])
#       labels.append(i[dim])
#     for m in range(len(x)):
#       for n in range(dim):
#         x[m][n] = float(x[m][n])
#     for k in range(len(labels)):
#       labels[k] = float(labels[k])
#   x = np.array(x, dtype=np.float32)
#   labels = np.array(labels, dtype=np.float32)
#   return x, labels, dim
def dataLoading(dataset):
  data,label = dataset
  dim = data.shape[1]
  return data, label, dim

# %%
dataset_1 = (data_tv,y_)
x1,x2,x3 = dataLoading(dataset_1)

# %%
# def writeResults(dataset, mean_aucroc, mean_aucpr, std_aucroc, std_aucpr):
#   path = "result.csv"
#   with open(path, 'a') as f:
#     #row = "dataset is " + dataset + ", mean_aucroc is " + str(mean_aucroc) + ", mean_aucpr is " + str(mean_aucpr) + ", std_aucroc is " + str(std_aucroc) + ", std_aucpr is " + str(std_aucpr) + '\n'
#     row = "pred is " + dataset + ",mean_aucroc is " + str(mean_aucroc) + ", mean_aucpr is " + str(mean_aucpr) + ", std_aucroc is " + str(std_aucroc) + ", std_aucpr is " + str(std_aucpr) + '\n'
#     f.write(row)
import matplotlib.pyplot as plt


def injectNoise(X_train, outlier_indices, n_cont, rand_seed):
  exchange_ratio = 0.05
  outlier_sample = X_train[outlier_indices]
  size, features = outlier_sample.shape
  noises_sample = np.empty((n_cont, features))
  n_exchange_features = int(features * exchange_ratio)
  rng = np.random.RandomState(rand_seed)
  outlier1, outlier2 = rng.choice(outlier_indices, 2, replace=False)
  exchange_features = rng.choice(features, n_exchange_features, replace=False)
  for i in range(n_cont):
    noises_sample[i] = X_train[outlier1]
    noises_sample[i, exchange_features] = X_train[outlier2][exchange_features]
  return noises_sample


class AEModel(torch.nn.Module):
  def __init__(self, dim) -> None:
    super().__init__()
    self.dim = dim
    self.en1 = torch.nn.Linear(dim, 128)
    self.en2 = torch.nn.Linear(128, 64)
    self.de1 = torch.nn.Linear(64, 128)
    self.de2 = torch.nn.Linear(128, dim)
    self.net = torch.nn.ModuleList([self.en1, self.en2, self.de1, self.de2])
  def forward(self, x):
    x = x.type(torch.float32)
    xen1 = torch.nn.functional.relu(self.en1(x))
    xen2 = torch.nn.functional.relu(self.en2(xen1))
    xde1 = torch.nn.functional.relu(self.de1(xen2))
    xde2 = torch.nn.functional.relu(self.de2(xde1))
    return xen2, xde2

def aesampler(X_train, batch_size, rng):
  ref = np.empty(batch_size, dtype=int)
  n_train = X_train.shape[0]
  for i in range(batch_size):
    inlier_id = rng.choice(n_train, 1)
    ref[i] = inlier_id
  return np.array(X_train[ref], dtype=np.float32)

def aefit(X_train, aemodel, epoch, batch_size, rng, device):
  lossfunc = torch.nn.MSELoss(reduction='mean')
  lossfunc = lossfunc.to(device)
  optimizer = torch.optim.Adam(params=aemodel.net.parameters(), lr=0.0001)
  for i in range(epoch):
    for j in range(0, 20):
      optimizer.zero_grad()
      data = aesampler(X_train, batch_size, rng)
      data = torch.from_numpy(data).to(device)
      en2, de2 = aemodel(data)
      en2 = en2.to(device)
      de2 = de2.to(device)
      loss = lossfunc(data.float(), de2.float())
      loss.backward()
      optimizer.step()
    print("ae epoch is {}, loss is {}".format(i + 1, loss))

class DevModel(torch.nn.Module):
  def __init__(self, aemodel, dim):
    super().__init__()
    self.aemodel = aemodel
    self.fc1 = torch.nn.Linear(dim + 64 + 1, 256)
    self.fc2 = torch.nn.Linear(256 + 1, 32)
    self.fc3 = torch.nn.Linear(32 + 1, 1)
    self.net = torch.nn.ModuleList([self.aemodel, self.fc1, self.fc2, self.fc3])
  def forward(self, x):
    en2, de2 = self.aemodel(x)
    sub_result = torch.sub(de2, x)
    recon_error = torch.norm(sub_result, p=2, dim=1)
    recon_error = recon_error.reshape(-1, 1)
    residual_error = sub_result / (recon_error + 1e-5)

    input_tensor = torch.cat([recon_error, residual_error, en2], dim=1)
    intermediate = torch.nn.functional.relu(self.fc1(input_tensor))
    intermediate = torch.cat([intermediate, recon_error], dim=1)
    intermediate = torch.nn.functional.relu(self.fc2(intermediate))
    intermediate = torch.cat([intermediate, recon_error], dim=1)
    intermediate = self.fc3(intermediate)
    return intermediate


def dev_loss(label, recon_error, pred):
  loss1 = torch.mean((1 - label) * recon_error + label * (torch.max(5 - recon_error, torch.zeros_like(recon_error))))
  loss2 = torch.mean((1 - label) * torch.squeeze(torch.abs(pred), dim=-1) + label * torch.squeeze(torch.max(5 - pred, torch.zeros_like(pred)), dim=-1))
  loss = loss1 + loss2
  return loss


def devsampler(X_train, y_train, batch_size, rng):
  ref = np.empty(batch_size, dtype=int)
  label = np.empty(batch_size)
  outlier_indices = np.where(y_train == 1)[0]
  inlier_indices = np.where(y_train == 0)[0]
  for i in range(batch_size):
    if(i % 2 == 0):
      outlier_id = rng.choice(outlier_indices, 1)
      ref[i] = outlier_id
      label[i] = y_train[outlier_id]
    else:
      inlier_id = rng.choice(inlier_indices, 1)
      ref[i] = inlier_id
      label[i] = y_train[inlier_id]
  return np.array(X_train[ref], dtype=np.float32), np.array(label, dtype=np.float32)


def devfit(X_train, y_train, devmodel, aemodel, epoch, batch_size, rng, device):
  optimizer = torch.optim.Adam(params=devmodel.net.parameters(), lr=0.0001)
  for i in range(epoch):
    for j in range(0, 20):
      optimizer.zero_grad()
      data, label = devsampler(X_train, y_train, batch_size, rng)
      data = torch.from_numpy(data).to(device)
      label = torch.from_numpy(label).to(device)
      en2, de2 = aemodel(data)
      de2 = de2.to(device)
      sub_result = torch.sub(de2, data)
      recon_error = torch.norm(sub_result, p=2, dim=1)
      pred = devmodel(data)
      muti_loss = dev_loss(label, recon_error, pred)
      muti_loss.backward()
      optimizer.step()
    print("dev epoch is {}, loss is {}".format(i + 1, muti_loss))



def run(args):
  # datasets = [os.path.splitext(_)[0] for _ in os.listdir(path='dataset')
  #             if os.path.splitext(_)[1] == '.csv']
  dataset = dataset_1
  rand_seed = args.rand_seed
  runs = args.runs
  known_outliers = args.known_outliers
  cont_rate = args.cont_rate
  epoch = args.epoch
  batch_size = args.batch_size
  device = torch.device("cuda:0")
  # for dataset in datasets:
    #dataset = dataset.strip()
  aucroc = torch.zeros(runs)
  aucpr = torch.zeros(runs)
  x, labels, dim = dataLoading(dataset)
  for i in range(runs):
    print("{} :round is {}".format(dataset, i + 1))
    test_ratio = 0.2
    X_train, X_test, y_train, y_test = train_test_split(x, labels, test_size=test_ratio, random_state=rand_seed, stratify=labels)
    outlier_indices = np.where(y_train == 1)[0]
    inlier_indices = np.where(y_train == 0)[0]
    n_inlier = inlier_indices.shape[0]
    n_outlier = outlier_indices.shape[0]
    rng = np.random.RandomState(rand_seed)
    print("Original training size is {}, Number of outliers in Training data is {}".format(X_train.shape[0], n_outlier))

    # Process labeled data
    if n_outlier > known_outliers:
      n_delete = n_outlier - known_outliers
      delete_indices = rng.choice(outlier_indices, size=n_delete, replace=False)
      X_train = np.delete(X_train, delete_indices, axis=0)
      y_train = np.delete(y_train, delete_indices, axis=0)
      n_outlier = known_outliers

    # Inject noises
    outlier_indices = np.where(y_train == 1)[0]
    n_cont = int(cont_rate * n_inlier / (1 - cont_rate))
    cont_sample = injectNoise(X_train, outlier_indices, n_cont, rand_seed)
    X_train = np.append(X_train, cont_sample, axis=0)
    y_train = np.append(y_train, np.zeros(n_cont), axis=0)
    print("Processed Train data number is {}, outliers number in Training data is {}, normal number in Traning data is {}".format(X_train.shape[0], n_outlier, n_inlier))
    n_outlier_test = np.where(y_test == 1)[0].shape[0]
    n_inlier_test = np.where(y_test == 0)[0].shape[0]
    print("Test data number is {}, outliers number is test data is {}, normal number in test data is {}".format(X_test.shape[0], n_outlier_test, n_inlier_test))

    #Pretrain AEModel
    print("pre-training start...")
    aemodel = AEModel(dim)
    aemodel = aemodel.to(device)
    aefit(X_train, aemodel, epoch, batch_size, rng, device)
    print("load autoencoder model...")

    #Train system
    print("end-to-end training start...")
    dev_model = DevModel(aemodel, dim)
    dev_model = dev_model.to(device)
    devfit(X_train, y_train, dev_model, aemodel, epoch, batch_size, rng, device)
    print("load model and print results...")

    X_test = torch.from_numpy(X_test.astype(np.float32)).to(device)
    pred = dev_model(X_test).squeeze(1)
    pred = pred.cpu().detach().numpy()
    aucroc[i] = roc_auc_score(y_score=pred, y_true=y_test)
    aucpr[i] = average_precision_score(y_score=pred, y_true=y_test)
    print("run is {}, aucroc is {:.6f}".format(i + 1, aucroc[i]))
    print("run is {}, aucpr is {:6f}".format(i + 1, aucpr[i]))

    mean_aucroc = torch.mean(aucroc).item()
    std_aucroc = torch.std(aucroc).item()
    mean_aucpr = torch.mean(aucpr).item()
    std_aucpr = torch.std(aucpr).item()
    print("average AUC-ROC is {:.6f}, average AUC-PR is {:.6f}".format(mean_aucroc, mean_aucpr))
    print("std AUC-ROC is {:.6f}, std AUC-PR is {:.6f}".format(std_aucroc, std_aucpr))
    # writeResults(pred.tolist(), mean_aucroc, mean_aucpr, std_aucroc, std_aucpr)
    plt.plot(pred)

# %%
# parser = argparse.ArgumentParser()
# parser.add_argument("--runs", type=int, default=10, help="how many times we repeat the experiment to obtain the average performance")
# parser.add_argument("--known_outliers", type=int, default=30, help="the number of labeled outliers available at hand")
# parser.add_argument("--cont_rate", type=float, default=0.02, help="the outlier contamination rate in the training data")
# parser.add_argument("--epoch", type=int, default=30, help="the number of epochs")
# parser.add_argument("--batch_size", type=int, default=512, help="the size of the batch")
# parser.add_argument("--rand_seed", type=int, default=42, help="the random seed number")
# #args = parser.parse_args()

# args =parser.parse_known_args()[0]



# run(args)

# %%
runs = 10
known_outliers = 20
cont_rate = 0.02
epoch = 10
batch_size = 64
rand_seed = 1

# %%
# datasets = [os.path.splitext(_)[0] for _ in os.listdir(path='dataset')
#             if os.path.splitext(_)[1] == '.csv']
dataset = dataset_1
# rand_seed = args.rand_seed
# runs = args.runs
# known_outliers = args.known_outliers
# cont_rate = args.cont_rate
# epoch = args.epoch
# batch_size = args.batch_size
device = torch.device("cuda:0")
# for dataset in datasets:
  #dataset = dataset.strip()
aucroc = torch.zeros(runs)
aucpr = torch.zeros(runs)
x, labels, dim = dataLoading(dataset)
for i in range(runs):
  print("{} :round is {}".format(dataset, i + 1))
  test_ratio = 0.2
  X_train, X_test, y_train, y_test = train_test_split(x, labels, test_size=test_ratio, random_state=rand_seed, stratify=labels)
  # X_test = data_1_
  y_test = np.concatenate((np.zeros(1000),np.ones(3920)))
  outlier_indices = np.where(y_train == 1)[0]
  inlier_indices = np.where(y_train == 0)[0]
  n_inlier = inlier_indices.shape[0]
  n_outlier = outlier_indices.shape[0]
  rng = np.random.RandomState(rand_seed)
  print("Original training size is {}, Number of outliers in Training data is {}".format(X_train.shape[0], n_outlier))

  # Process labeled data
  if n_outlier > known_outliers:
    n_delete = n_outlier - known_outliers
    delete_indices = rng.choice(outlier_indices, size=n_delete, replace=False)
    X_train = np.delete(X_train, delete_indices, axis=0)
    y_train = np.delete(y_train, delete_indices, axis=0)
    n_outlier = known_outliers

  # Inject noises
  outlier_indices = np.where(y_train == 1)[0]
  n_cont = int(cont_rate * n_inlier / (1 - cont_rate))
  cont_sample = injectNoise(X_train, outlier_indices, n_cont, rand_seed)
  X_train = np.append(X_train, cont_sample, axis=0)
  y_train = np.append(y_train, np.zeros(n_cont), axis=0)
  print("Processed Train data number is {}, outliers number in Training data is {}, normal number in Traning data is {}".format(X_train.shape[0], n_outlier, n_inlier))
  n_outlier_test = np.where(y_test == 1)[0].shape[0]
  n_inlier_test = np.where(y_test == 0)[0].shape[0]
  print("Test data number is {}, outliers number is test data is {}, normal number in test data is {}".format(X_test.shape[0], n_outlier_test, n_inlier_test))

  #Pretrain AEModel
  print("pre-training start...")
  aemodel = AEModel(dim)
  aemodel = aemodel.to(device)
  aefit(X_train, aemodel, epoch, batch_size, rng, device)
  print("load autoencoder model...")

  #Train system
  print("end-to-end training start...")
  dev_model = DevModel(aemodel, dim)
  dev_model = dev_model.to(device)
  devfit(X_train, y_train, dev_model, aemodel, epoch, batch_size, rng, device)
  print("load model and print results...")

  X_test = torch.from_numpy(data_tva.astype(np.float32)).to(device)
  # X_test = torch.from_numpy(X_test.astype(np.float32)).to(device)
  pred = dev_model(X_test).squeeze(1)
  pred = pred.cpu().detach().numpy()
  aucroc[i] = roc_auc_score(y_score=pred, y_true=y_test)
  aucpr[i] = average_precision_score(y_score=pred, y_true=y_test)
  print("run is {}, aucroc is {:.6f}".format(i + 1, aucroc[i]))
  print("run is {}, aucpr is {:6f}".format(i + 1, aucpr[i]))

  mean_aucroc = torch.mean(aucroc).item()
  std_aucroc = torch.std(aucroc).item()
  mean_aucpr = torch.mean(aucpr).item()
  std_aucpr = torch.std(aucpr).item()
  print("average AUC-ROC is {:.6f}, average AUC-PR is {:.6f}".format(mean_aucroc, mean_aucpr))
  print("std AUC-ROC is {:.6f}, std AUC-PR is {:.6f}".format(std_aucroc, std_aucpr))
  # writeResults(pred.tolist(), mean_aucroc, mean_aucpr, std_aucroc, std_aucpr)
  plt.figure(figsize = (10,3))
  plt.plot(pred)
  plt.show()
# Out:
# (array([[0.6057047 , 0.64261745, 0.71644295, ..., 0.47986577, 0.59899329,
#         0.46644295],
#        [0.35738255, 0.40939597, 0.41442953, ..., 0.60234899, 0.53355705,
#         0.5033557 ],
#        [0.4911032 , 0.50355872, 0.51245552, ..., 0.46975089, 0.4341637 ,
#         0.39145907],
#        ...,
#        [0.30658436, 0.26131687, 0.31687243, ..., 0.49794239, 0.43209877,
#         0.43621399],
#        [0.49230769, 0.47884615, 0.29038462, ..., 0.3       , 0.35576923,
#         0.42115385],
#        [0.58075041, 0.46492659, 0.71288744, ..., 0.55301794, 0.50570962,
#         0.57748777]]), array([0., 0., 0., ..., 1., 1., 1.])) :round is 1
# Original training size is 816, Number of outliers in Training data is 16
# Processed Train data number is 832, outliers number in Training data is 16, normal number in Traning data is 800
# Test data number is 204, outliers number is test data is 3920, normal number in test data is 1000
# pre-training start...
# ae epoch is 1, loss is 0.17702758312225342
# ae epoch is 2, loss is 0.14889904856681824
# ae epoch is 3, loss is 0.131791889667511
# <ipython-input-55-a2f8d672e426>:47: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ref[i] = inlier_id
# <ipython-input-55-a2f8d672e426>:47: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ref[i] = inlier_id
# ae epoch is 4, loss is 0.12355350703001022
# ae epoch is 5, loss is 0.1183231994509697
# ae epoch is 6, loss is 0.11861373484134674
# ae epoch is 7, loss is 0.12051402032375336
# ae epoch is 8, loss is 0.11847291886806488
# ae epoch is 9, loss is 0.12029272317886353
# ae epoch is 10, loss is 0.11463325470685959
# load autoencoder model...
# end-to-end training start...
# dev epoch is 1, loss is 16.39310073852539
# <ipython-input-55-a2f8d672e426>:106: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ref[i] = outlier_id
# <ipython-input-55-a2f8d672e426>:107: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   label[i] = y_train[outlier_id]
# <ipython-input-55-a2f8d672e426>:110: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ref[i] = inlier_id
# <ipython-input-55-a2f8d672e426>:111: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   label[i] = y_train[inlier_id]
# dev epoch is 2, loss is 15.611686706542969
# dev epoch is 3, loss is 14.33246898651123
# dev epoch is 4, loss is 12.846803665161133
# dev epoch is 5, loss is 12.796749114990234
# dev epoch is 6, loss is 12.796920776367188
# dev epoch is 7, loss is 12.646295547485352
# dev epoch is 8, loss is 12.647797584533691
# dev epoch is 9, loss is 12.71468734741211
# dev epoch is 10, loss is 12.537483215332031
# load model and print results...
# run is 1, aucroc is 0.461183
# run is 1, aucpr is 0.786318
# average AUC-ROC is 0.046118, average AUC-PR is 0.078632
# std AUC-ROC is 0.145839, std AUC-PR is 0.248656
# <ipython-input-55-a2f8d672e426>:106: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ref[i] = outlier_id
# <ipython-input-55-a2f8d672e426>:107: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   label[i] = y_train[outlier_id]
# <ipython-input-55-a2f8d672e426>:110: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ref[i] = inlier_id
# <ipython-input-55-a2f8d672e426>:111: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   label[i] = y_train[inlier_id]
# (array([[0.6057047 , 0.64261745, 0.71644295, ..., 0.47986577, 0.59899329,
#         0.46644295],
#        [0.35738255, 0.40939597, 0.41442953, ..., 0.60234899, 0.53355705,
#         0.5033557 ],
#        [0.4911032 , 0.50355872, 0.51245552, ..., 0.46975089, 0.4341637 ,
#         0.39145907],
#        ...,
#        [0.30658436, 0.26131687, 0.31687243, ..., 0.49794239, 0.43209877,
#         0.43621399],
#        [0.49230769, 0.47884615, 0.29038462, ..., 0.3       , 0.35576923,
#         0.42115385],
#        [0.58075041, 0.46492659, 0.71288744, ..., 0.55301794, 0.50570962,
#         0.57748777]]), array([0., 0., 0., ..., 1., 1., 1.])) :round is 2
# Original training size is 816, Number of outliers in Training data is 16
# Processed Train data number is 832, outliers number in Training data is 16, normal number in Traning data is 800
# Test data number is 204, outliers number is test data is 3920, normal number in test data is 1000
# pre-training start...
# ae epoch is 1, loss is 0.17634132504463196
# ae epoch is 2, loss is 0.14812874794006348
# ae epoch is 3, loss is 0.13155920803546906
# ae epoch is 4, loss is 0.12380202114582062
# ae epoch is 5, loss is 0.11960186809301376
# ae epoch is 6, loss is 0.11970803141593933
# ae epoch is 7, loss is 0.1216885969042778
# ae epoch is 8, loss is 0.1198895275592804
# ae epoch is 9, loss is 0.12131626904010773
# ae epoch is 10, loss is 0.11593188345432281
# load autoencoder model...
# end-to-end training start...
# dev epoch is 1, loss is 13.649272918701172
# dev epoch is 2, loss is 13.375985145568848
# dev epoch is 3, loss is 13.149169921875
# dev epoch is 4, loss is 13.095184326171875
# dev epoch is 5, loss is 13.096637725830078
# dev epoch is 6, loss is 13.089750289916992
# dev epoch is 7, loss is 12.74604320526123
# dev epoch is 8, loss is 12.437919616699219
# dev epoch is 9, loss is 12.170951843261719
# dev epoch is 10, loss is 11.644628524780273
# load model and print results...
# run is 2, aucroc is 0.494831
# run is 2, aucpr is 0.795261
# average AUC-ROC is 0.095601, average AUC-PR is 0.158158
# std AUC-ROC is 0.201702, std AUC-PR is 0.333433
# <ipython-input-55-a2f8d672e426>:47: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ref[i] = inlier_id
# <ipython-input-55-a2f8d672e426>:47: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ref[i] = inlier_id
# <ipython-input-55-a2f8d672e426>:106: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ref[i] = outlier_id
# <ipython-input-55-a2f8d672e426>:107: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   label[i] = y_train[outlier_id]
# <ipython-input-55-a2f8d672e426>:110: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ref[i] = inlier_id
# <ipython-input-55-a2f8d672e426>:111: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   label[i] = y_train[inlier_id]
# (array([[0.6057047 , 0.64261745, 0.71644295, ..., 0.47986577, 0.59899329,
#         0.46644295],
#        [0.35738255, 0.40939597, 0.41442953, ..., 0.60234899, 0.53355705,
#         0.5033557 ],
#        [0.4911032 , 0.50355872, 0.51245552, ..., 0.46975089, 0.4341637 ,
#         0.39145907],
#        ...,
#        [0.30658436, 0.26131687, 0.31687243, ..., 0.49794239, 0.43209877,
#         0.43621399],
#        [0.49230769, 0.47884615, 0.29038462, ..., 0.3       , 0.35576923,
#         0.42115385],
#        [0.58075041, 0.46492659, 0.71288744, ..., 0.55301794, 0.50570962,
#         0.57748777]]), array([0., 0., 0., ..., 1., 1., 1.])) :round is 3
# Original training size is 816, Number of outliers in Training data is 16
# Processed Train data number is 832, outliers number in Training data is 16, normal number in Traning data is 800
# Test data number is 204, outliers number is test data is 3920, normal number in test data is 1000
# pre-training start...
# ae epoch is 1, loss is 0.1756979376077652
# ae epoch is 2, loss is 0.14861667156219482
# <ipython-input-55-a2f8d672e426>:47: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ref[i] = inlier_id
# ae epoch is 3, loss is 0.13170795142650604
# ae epoch is 4, loss is 0.12364630401134491
# ae epoch is 5, loss is 0.11948364973068237
# ae epoch is 6, loss is 0.11990001797676086
# ae epoch is 7, loss is 0.12201212346553802
# ae epoch is 8, loss is 0.11998318135738373
# ae epoch is 9, loss is 0.12160391360521317
# ae epoch is 10, loss is 0.11590846627950668
# load autoencoder model...
# end-to-end training start...
# <ipython-input-55-a2f8d672e426>:106: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ref[i] = outlier_id
# <ipython-input-55-a2f8d672e426>:107: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   label[i] = y_train[outlier_id]
# <ipython-input-55-a2f8d672e426>:110: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ref[i] = inlier_id
# <ipython-input-55-a2f8d672e426>:111: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   label[i] = y_train[inlier_id]
# dev epoch is 1, loss is 13.643977165222168
# dev epoch is 2, loss is 13.373095512390137
# dev epoch is 3, loss is 13.155439376831055
# dev epoch is 4, loss is 13.09878921508789
# dev epoch is 5, loss is 13.016878128051758
# dev epoch is 6, loss is 12.88607120513916
# dev epoch is 7, loss is 12.514423370361328
# dev epoch is 8, loss is 12.238203048706055
# dev epoch is 9, loss is 11.867286682128906
# dev epoch is 10, loss is 11.299249649047852
# load model and print results...
# run is 3, aucroc is 0.494578
# run is 3, aucpr is 0.794249
# average AUC-ROC is 0.145059, average AUC-PR is 0.237583
# std AUC-ROC is 0.233746, std AUC-PR is 0.382552
# <ipython-input-55-a2f8d672e426>:106: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ref[i] = outlier_id
# <ipython-input-55-a2f8d672e426>:107: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   label[i] = y_train[outlier_id]
# <ipython-input-55-a2f8d672e426>:110: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ref[i] = inlier_id
# <ipython-input-55-a2f8d672e426>:111: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   label[i] = y_train[inlier_id]
# (array([[0.6057047 , 0.64261745, 0.71644295, ..., 0.47986577, 0.59899329,
#         0.46644295],
#        [0.35738255, 0.40939597, 0.41442953, ..., 0.60234899, 0.53355705,
#         0.5033557 ],
#        [0.4911032 , 0.50355872, 0.51245552, ..., 0.46975089, 0.4341637 ,
#         0.39145907],
#        ...,
#        [0.30658436, 0.26131687, 0.31687243, ..., 0.49794239, 0.43209877,
#         0.43621399],
#        [0.49230769, 0.47884615, 0.29038462, ..., 0.3       , 0.35576923,
#         0.42115385],
#        [0.58075041, 0.46492659, 0.71288744, ..., 0.55301794, 0.50570962,
#         0.57748777]]), array([0., 0., 0., ..., 1., 1., 1.])) :round is 4
# Original training size is 816, Number of outliers in Training data is 16
# Processed Train data number is 832, outliers number in Training data is 16, normal number in Traning data is 800
# Test data number is 204, outliers number is test data is 3920, normal number in test data is 1000
# pre-training start...
# ae epoch is 1, loss is 0.17411530017852783
# ae epoch is 2, loss is 0.14910084009170532
# ae epoch is 3, loss is 0.13208763301372528
# <ipython-input-55-a2f8d672e426>:47: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ref[i] = inlier_id
# <ipython-input-55-a2f8d672e426>:47: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ref[i] = inlier_id
# ae epoch is 4, loss is 0.12358849495649338
# ae epoch is 5, loss is 0.11910761892795563
# ae epoch is 6, loss is 0.11874699592590332
# ae epoch is 7, loss is 0.1199827790260315
# ae epoch is 8, loss is 0.11764898896217346
# ae epoch is 9, loss is 0.11913357675075531
# ae epoch is 10, loss is 0.11362101882696152
# load autoencoder model...
# end-to-end training start...
# dev epoch is 1, loss is 13.565574645996094
# <ipython-input-55-a2f8d672e426>:106: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ref[i] = outlier_id
# <ipython-input-55-a2f8d672e426>:107: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   label[i] = y_train[outlier_id]
# <ipython-input-55-a2f8d672e426>:110: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ref[i] = inlier_id
# <ipython-input-55-a2f8d672e426>:111: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   label[i] = y_train[inlier_id]
# dev epoch is 2, loss is 13.30561351776123
# dev epoch is 3, loss is 13.033806800842285
# dev epoch is 4, loss is 12.983569145202637
# dev epoch is 5, loss is 12.982649803161621
# <ipython-input-55-a2f8d672e426>:106: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ref[i] = outlier_id
# <ipython-input-55-a2f8d672e426>:107: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   label[i] = y_train[outlier_id]
# <ipython-input-55-a2f8d672e426>:110: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ref[i] = inlier_id
# <ipython-input-55-a2f8d672e426>:111: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   label[i] = y_train[inlier_id]
# dev epoch is 6, loss is 12.948922157287598
# dev epoch is 7, loss is 12.564520835876465
# dev epoch is 8, loss is 12.258227348327637
# dev epoch is 9, loss is 11.95703125
# dev epoch is 10, loss is 11.606084823608398
# load model and print results...
# run is 4, aucroc is 0.497689
# run is 4, aucpr is 0.796441
# average AUC-ROC is 0.194828, average AUC-PR is 0.317227
# std AUC-ROC is 0.251721, std AUC-PR is 0.409547
# (array([[0.6057047 , 0.64261745, 0.71644295, ..., 0.47986577, 0.59899329,
#         0.46644295],
#        [0.35738255, 0.40939597, 0.41442953, ..., 0.60234899, 0.53355705,
#         0.5033557 ],
#        [0.4911032 , 0.50355872, 0.51245552, ..., 0.46975089, 0.4341637 ,
#         0.39145907],
#        ...,
#        [0.30658436, 0.26131687, 0.31687243, ..., 0.49794239, 0.43209877,
#         0.43621399],
#        [0.49230769, 0.47884615, 0.29038462, ..., 0.3       , 0.35576923,
#         0.42115385],
#        [0.58075041, 0.46492659, 0.71288744, ..., 0.55301794, 0.50570962,
#         0.57748777]]), array([0., 0., 0., ..., 1., 1., 1.])) :round is 5
# Original training size is 816, Number of outliers in Training data is 16
# Processed Train data number is 832, outliers number in Training data is 16, normal number in Traning data is 800
# Test data number is 204, outliers number is test data is 3920, normal number in test data is 1000
# pre-training start...
# ae epoch is 1, loss is 0.1763707399368286
# ae epoch is 2, loss is 0.14779916405677795
# <ipython-input-55-a2f8d672e426>:47: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ref[i] = inlier_id
# ae epoch is 3, loss is 0.13010242581367493
# ae epoch is 4, loss is 0.12048783153295517
# ae epoch is 5, loss is 0.11439361423254013
# ae epoch is 6, loss is 0.11381207406520844
# ae epoch is 7, loss is 0.11511041224002838
# ae epoch is 8, loss is 0.11276945471763611
# ae epoch is 9, loss is 0.11390171945095062
# ae epoch is 10, loss is 0.10874773561954498
# load autoencoder model...
# end-to-end training start...
# dev epoch is 1, loss is 13.300455093383789
# dev epoch is 2, loss is 13.032150268554688
# dev epoch is 3, loss is 12.792530059814453
# dev epoch is 4, loss is 12.72458553314209
# dev epoch is 5, loss is 12.693464279174805
# <ipython-input-55-a2f8d672e426>:106: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ref[i] = outlier_id
# <ipython-input-55-a2f8d672e426>:107: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   label[i] = y_train[outlier_id]
# <ipython-input-55-a2f8d672e426>:110: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ref[i] = inlier_id
# <ipython-input-55-a2f8d672e426>:111: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   label[i] = y_train[inlier_id]
# <ipython-input-55-a2f8d672e426>:106: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ref[i] = outlier_id
# <ipython-input-55-a2f8d672e426>:107: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   label[i] = y_train[outlier_id]
# <ipython-input-55-a2f8d672e426>:110: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ref[i] = inlier_id
# <ipython-input-55-a2f8d672e426>:111: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   label[i] = y_train[inlier_id]
# dev epoch is 6, loss is 12.627666473388672
# dev epoch is 7, loss is 12.34567928314209
# dev epoch is 8, loss is 12.18452262878418
# dev epoch is 9, loss is 11.890669822692871
# <ipython-input-55-a2f8d672e426>:106: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ref[i] = outlier_id
# <ipython-input-55-a2f8d672e426>:107: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   label[i] = y_train[outlier_id]
# <ipython-input-55-a2f8d672e426>:110: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ref[i] = inlier_id
# <ipython-input-55-a2f8d672e426>:111: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   label[i] = y_train[inlier_id]
# dev epoch is 10, loss is 11.226821899414062
# load model and print results...
# run is 5, aucroc is 0.495700
# run is 5, aucpr is 0.794893
# average AUC-ROC is 0.244398, average AUC-PR is 0.396716
# std AUC-ROC is 0.257825, std AUC-PR is 0.418184
# (array([[0.6057047 , 0.64261745, 0.71644295, ..., 0.47986577, 0.59899329,
#         0.46644295],
#        [0.35738255, 0.40939597, 0.41442953, ..., 0.60234899, 0.53355705,
#         0.5033557 ],
#        [0.4911032 , 0.50355872, 0.51245552, ..., 0.46975089, 0.4341637 ,
#         0.39145907],
#        ...,
#        [0.30658436, 0.26131687, 0.31687243, ..., 0.49794239, 0.43209877,
#         0.43621399],
#        [0.49230769, 0.47884615, 0.29038462, ..., 0.3       , 0.35576923,
#         0.42115385],
#        [0.58075041, 0.46492659, 0.71288744, ..., 0.55301794, 0.50570962,
#         0.57748777]]), array([0., 0., 0., ..., 1., 1., 1.])) :round is 6
# Original training size is 816, Number of outliers in Training data is 16
# Processed Train data number is 832, outliers number in Training data is 16, normal number in Traning data is 800
# Test data number is 204, outliers number is test data is 3920, normal number in test data is 1000
# pre-training start...
# ae epoch is 1, loss is 0.17730370163917542
# <ipython-input-55-a2f8d672e426>:47: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ref[i] = inlier_id
# ae epoch is 2, loss is 0.15003547072410583
# ae epoch is 3, loss is 0.13292375206947327
# ae epoch is 4, loss is 0.12456446886062622
# ae epoch is 5, loss is 0.11977884918451309
# ae epoch is 6, loss is 0.12017984688282013
# ae epoch is 7, loss is 0.12237410247325897
# ae epoch is 8, loss is 0.11994826793670654
# ae epoch is 9, loss is 0.12181654572486877
# ae epoch is 10, loss is 0.11648835241794586
# load autoencoder model...
# end-to-end training start...
# dev epoch is 1, loss is 15.58528995513916
# dev epoch is 2, loss is 14.705446243286133
# <ipython-input-55-a2f8d672e426>:106: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ref[i] = outlier_id
# <ipython-input-55-a2f8d672e426>:107: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   label[i] = y_train[outlier_id]
# <ipython-input-55-a2f8d672e426>:110: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ref[i] = inlier_id
# <ipython-input-55-a2f8d672e426>:111: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   label[i] = y_train[inlier_id]
# <ipython-input-55-a2f8d672e426>:106: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ref[i] = outlier_id
# <ipython-input-55-a2f8d672e426>:107: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   label[i] = y_train[outlier_id]
# <ipython-input-55-a2f8d672e426>:110: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ref[i] = inlier_id
# <ipython-input-55-a2f8d672e426>:111: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   label[i] = y_train[inlier_id]
# dev epoch is 3, loss is 13.584589004516602
# dev epoch is 4, loss is 12.882122993469238
# dev epoch is 5, loss is 12.869856834411621
# dev epoch is 6, loss is 12.854052543640137
# dev epoch is 7, loss is 12.668691635131836
# dev epoch is 8, loss is 12.706514358520508
# dev epoch is 9, loss is 12.746631622314453
# dev epoch is 10, loss is 12.6373291015625
# load model and print results...
# run is 6, aucroc is 0.451795
# run is 6, aucpr is 0.775137
# average AUC-ROC is 0.289578, average AUC-PR is 0.474230
# std AUC-ROC is 0.249697, std AUC-PR is 0.408199
# <ipython-input-55-a2f8d672e426>:106: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ref[i] = outlier_id
# <ipython-input-55-a2f8d672e426>:107: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   label[i] = y_train[outlier_id]
# <ipython-input-55-a2f8d672e426>:110: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ref[i] = inlier_id
# <ipython-input-55-a2f8d672e426>:111: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   label[i] = y_train[inlier_id]
# <ipython-input-55-a2f8d672e426>:106: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ref[i] = outlier_id
# <ipython-input-55-a2f8d672e426>:107: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   label[i] = y_train[outlier_id]
# <ipython-input-55-a2f8d672e426>:110: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ref[i] = inlier_id
# <ipython-input-55-a2f8d672e426>:111: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   label[i] = y_train[inlier_id]
# (array([[0.6057047 , 0.64261745, 0.71644295, ..., 0.47986577, 0.59899329,
#         0.46644295],
#        [0.35738255, 0.40939597, 0.41442953, ..., 0.60234899, 0.53355705,
#         0.5033557 ],
#        [0.4911032 , 0.50355872, 0.51245552, ..., 0.46975089, 0.4341637 ,
#         0.39145907],
#        ...,
#        [0.30658436, 0.26131687, 0.31687243, ..., 0.49794239, 0.43209877,
#         0.43621399],
#        [0.49230769, 0.47884615, 0.29038462, ..., 0.3       , 0.35576923,
#         0.42115385],
#        [0.58075041, 0.46492659, 0.71288744, ..., 0.55301794, 0.50570962,
#         0.57748777]]), array([0., 0., 0., ..., 1., 1., 1.])) :round is 7
# Original training size is 816, Number of outliers in Training data is 16
# Processed Train data number is 832, outliers number in Training data is 16, normal number in Traning data is 800
# Test data number is 204, outliers number is test data is 3920, normal number in test data is 1000
# pre-training start...
# ae epoch is 1, loss is 0.17647527158260345
# ae epoch is 2, loss is 0.14856170117855072
# <ipython-input-55-a2f8d672e426>:47: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ref[i] = inlier_id
# ae epoch is 3, loss is 0.13121852278709412
# ae epoch is 4, loss is 0.12223885208368301
# ae epoch is 5, loss is 0.11675965785980225
# ae epoch is 6, loss is 0.11625809967517853
# ae epoch is 7, loss is 0.11754248291254044
# ae epoch is 8, loss is 0.11470892280340195
# ae epoch is 9, loss is 0.11582344025373459
# ae epoch is 10, loss is 0.11068899929523468
# load autoencoder model...
# end-to-end training start...
# dev epoch is 1, loss is 15.267524719238281
# dev epoch is 2, loss is 14.238601684570312
# dev epoch is 3, loss is 13.124387741088867
# <ipython-input-55-a2f8d672e426>:106: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ref[i] = outlier_id
# <ipython-input-55-a2f8d672e426>:107: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   label[i] = y_train[outlier_id]
# <ipython-input-55-a2f8d672e426>:110: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ref[i] = inlier_id
# <ipython-input-55-a2f8d672e426>:111: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   label[i] = y_train[inlier_id]
# <ipython-input-55-a2f8d672e426>:106: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ref[i] = outlier_id
# <ipython-input-55-a2f8d672e426>:107: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   label[i] = y_train[outlier_id]
# <ipython-input-55-a2f8d672e426>:110: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ref[i] = inlier_id
# <ipython-input-55-a2f8d672e426>:111: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   label[i] = y_train[inlier_id]
# dev epoch is 4, loss is 12.581031799316406
# dev epoch is 5, loss is 12.559861183166504
# dev epoch is 6, loss is 12.587325096130371
# dev epoch is 7, loss is 12.447044372558594
# dev epoch is 8, loss is 12.464202880859375
# dev epoch is 9, loss is 12.54785442352295
# dev epoch is 10, loss is 12.457059860229492
# load model and print results...
# run is 7, aucroc is 0.458791
# run is 7, aucpr is 0.786643
# average AUC-ROC is 0.335457, average AUC-PR is 0.552894
# std AUC-ROC is 0.232107, std AUC-PR is 0.381585
# (array([[0.6057047 , 0.64261745, 0.71644295, ..., 0.47986577, 0.59899329,
#         0.46644295],
#        [0.35738255, 0.40939597, 0.41442953, ..., 0.60234899, 0.53355705,
#         0.5033557 ],
#        [0.4911032 , 0.50355872, 0.51245552, ..., 0.46975089, 0.4341637 ,
#         0.39145907],
#        ...,
#        [0.30658436, 0.26131687, 0.31687243, ..., 0.49794239, 0.43209877,
#         0.43621399],
#        [0.49230769, 0.47884615, 0.29038462, ..., 0.3       , 0.35576923,
#         0.42115385],
#        [0.58075041, 0.46492659, 0.71288744, ..., 0.55301794, 0.50570962,
#         0.57748777]]), array([0., 0., 0., ..., 1., 1., 1.])) :round is 8
# Original training size is 816, Number of outliers in Training data is 16
# Processed Train data number is 832, outliers number in Training data is 16, normal number in Traning data is 800
# Test data number is 204, outliers number is test data is 3920, normal number in test data is 1000
# pre-training start...
# ae epoch is 1, loss is 0.1741531491279602
# ae epoch is 2, loss is 0.1449609100818634
# ae epoch is 3, loss is 0.1293150633573532
# <ipython-input-55-a2f8d672e426>:47: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ref[i] = inlier_id
# <ipython-input-55-a2f8d672e426>:47: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ref[i] = inlier_id
# ae epoch is 4, loss is 0.1215851902961731
# ae epoch is 5, loss is 0.11691945791244507
# ae epoch is 6, loss is 0.11697779595851898
# ae epoch is 7, loss is 0.11916742473840714
# ae epoch is 8, loss is 0.11723991483449936
# ae epoch is 9, loss is 0.11904747784137726
# ae epoch is 10, loss is 0.11383631825447083
# load autoencoder model...
# end-to-end training start...
# dev epoch is 1, loss is 13.592510223388672
# <ipython-input-55-a2f8d672e426>:106: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ref[i] = outlier_id
# <ipython-input-55-a2f8d672e426>:107: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   label[i] = y_train[outlier_id]
# <ipython-input-55-a2f8d672e426>:110: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ref[i] = inlier_id
# <ipython-input-55-a2f8d672e426>:111: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   label[i] = y_train[inlier_id]
# dev epoch is 2, loss is 13.316980361938477
# dev epoch is 3, loss is 13.063814163208008
# dev epoch is 4, loss is 13.021464347839355
# dev epoch is 5, loss is 13.011845588684082
# dev epoch is 6, loss is 12.969149589538574
# dev epoch is 7, loss is 12.589489936828613
# dev epoch is 8, loss is 12.116743087768555
# <ipython-input-55-a2f8d672e426>:106: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ref[i] = outlier_id
# <ipython-input-55-a2f8d672e426>:107: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   label[i] = y_train[outlier_id]
# <ipython-input-55-a2f8d672e426>:110: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ref[i] = inlier_id
# <ipython-input-55-a2f8d672e426>:111: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   label[i] = y_train[inlier_id]
# <ipython-input-55-a2f8d672e426>:106: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ref[i] = outlier_id
# <ipython-input-55-a2f8d672e426>:107: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   label[i] = y_train[outlier_id]
# <ipython-input-55-a2f8d672e426>:110: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ref[i] = inlier_id
# <ipython-input-55-a2f8d672e426>:111: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   label[i] = y_train[inlier_id]
# dev epoch is 9, loss is 11.491539001464844
# dev epoch is 10, loss is 11.00253677368164
# load model and print results...
# run is 8, aucroc is 0.499174
# run is 8, aucpr is 0.797912
# average AUC-ROC is 0.385374, average AUC-PR is 0.632685
# std AUC-ROC is 0.203911, std AUC-PR is 0.333523
# (array([[0.6057047 , 0.64261745, 0.71644295, ..., 0.47986577, 0.59899329,
#         0.46644295],
#        [0.35738255, 0.40939597, 0.41442953, ..., 0.60234899, 0.53355705,
#         0.5033557 ],
#        [0.4911032 , 0.50355872, 0.51245552, ..., 0.46975089, 0.4341637 ,
#         0.39145907],
#        ...,
#        [0.30658436, 0.26131687, 0.31687243, ..., 0.49794239, 0.43209877,
#         0.43621399],
#        [0.49230769, 0.47884615, 0.29038462, ..., 0.3       , 0.35576923,
#         0.42115385],
#        [0.58075041, 0.46492659, 0.71288744, ..., 0.55301794, 0.50570962,
#         0.57748777]]), array([0., 0., 0., ..., 1., 1., 1.])) :round is 9
# Original training size is 816, Number of outliers in Training data is 16
# Processed Train data number is 832, outliers number in Training data is 16, normal number in Traning data is 800
# Test data number is 204, outliers number is test data is 3920, normal number in test data is 1000
# pre-training start...
# ae epoch is 1, loss is 0.17883789539337158
# ae epoch is 2, loss is 0.15100660920143127
# <ipython-input-55-a2f8d672e426>:47: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ref[i] = inlier_id
# ae epoch is 3, loss is 0.13386107981204987
# ae epoch is 4, loss is 0.12580506503582
# ae epoch is 5, loss is 0.12052550911903381
# ae epoch is 6, loss is 0.12041081488132477
# ae epoch is 7, loss is 0.122285857796669
# ae epoch is 8, loss is 0.11987470090389252
# <ipython-input-55-a2f8d672e426>:47: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ref[i] = inlier_id
# <ipython-input-55-a2f8d672e426>:106: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ref[i] = outlier_id
# <ipython-input-55-a2f8d672e426>:107: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   label[i] = y_train[outlier_id]
# <ipython-input-55-a2f8d672e426>:110: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ref[i] = inlier_id
# <ipython-input-55-a2f8d672e426>:111: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   label[i] = y_train[inlier_id]
# ae epoch is 9, loss is 0.12147095799446106
# ae epoch is 10, loss is 0.11608840525150299
# load autoencoder model...
# end-to-end training start...
# dev epoch is 1, loss is 15.188053131103516
# dev epoch is 2, loss is 14.461288452148438
# dev epoch is 3, loss is 13.703374862670898
# dev epoch is 4, loss is 12.905807495117188
# dev epoch is 5, loss is 12.867115020751953
# dev epoch is 6, loss is 12.904275894165039
# dev epoch is 7, loss is 12.728796005249023
# dev epoch is 8, loss is 12.749093055725098
# dev epoch is 9, loss is 12.839473724365234
# dev epoch is 10, loss is 12.739371299743652
# load model and print results...
# run is 9, aucroc is 0.443575
# run is 9, aucpr is 0.773577
# average AUC-ROC is 0.429732, average AUC-PR is 0.710043
# std AUC-ROC is 0.152540, std AUC-PR is 0.249635
# (array([[0.6057047 , 0.64261745, 0.71644295, ..., 0.47986577, 0.59899329,
#         0.46644295],
#        [0.35738255, 0.40939597, 0.41442953, ..., 0.60234899, 0.53355705,
#         0.5033557 ],
#        [0.4911032 , 0.50355872, 0.51245552, ..., 0.46975089, 0.4341637 ,
#         0.39145907],
#        ...,
#        [0.30658436, 0.26131687, 0.31687243, ..., 0.49794239, 0.43209877,
#         0.43621399],
#        [0.49230769, 0.47884615, 0.29038462, ..., 0.3       , 0.35576923,
#         0.42115385],
#        [0.58075041, 0.46492659, 0.71288744, ..., 0.55301794, 0.50570962,
#         0.57748777]]), array([0., 0., 0., ..., 1., 1., 1.])) :round is 10
# Original training size is 816, Number of outliers in Training data is 16
# Processed Train data number is 832, outliers number in Training data is 16, normal number in Traning data is 800
# Test data number is 204, outliers number is test data is 3920, normal number in test data is 1000
# pre-training start...
# ae epoch is 1, loss is 0.17572052776813507
# ae epoch is 2, loss is 0.1480945646762848
# ae epoch is 3, loss is 0.1319759339094162
# ae epoch is 4, loss is 0.12443332374095917
# ae epoch is 5, loss is 0.12063954025506973
# ae epoch is 6, loss is 0.12103182077407837
# ae epoch is 7, loss is 0.12326525151729584
# ae epoch is 8, loss is 0.12093760073184967
# ae epoch is 9, loss is 0.12245339155197144
# <ipython-input-55-a2f8d672e426>:47: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ref[i] = inlier_id
# <ipython-input-55-a2f8d672e426>:47: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ref[i] = inlier_id
# ae epoch is 10, loss is 0.1166149154305458
# load autoencoder model...
# end-to-end training start...
# dev epoch is 1, loss is 15.52847671508789
# <ipython-input-55-a2f8d672e426>:106: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ref[i] = outlier_id
# <ipython-input-55-a2f8d672e426>:107: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   label[i] = y_train[outlier_id]
# <ipython-input-55-a2f8d672e426>:110: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ref[i] = inlier_id
# <ipython-input-55-a2f8d672e426>:111: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   label[i] = y_train[inlier_id]
# <ipython-input-55-a2f8d672e426>:106: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ref[i] = outlier_id
# <ipython-input-55-a2f8d672e426>:107: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   label[i] = y_train[outlier_id]
# <ipython-input-55-a2f8d672e426>:110: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ref[i] = inlier_id
# <ipython-input-55-a2f8d672e426>:111: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   label[i] = y_train[inlier_id]
# dev epoch is 2, loss is 13.952666282653809
# dev epoch is 3, loss is 13.029492378234863
# dev epoch is 4, loss is 12.953023910522461
# dev epoch is 5, loss is 13.012164115905762
# dev epoch is 6, loss is 13.057868957519531
# dev epoch is 7, loss is 12.883000373840332
# dev epoch is 8, loss is 12.898764610290527
# dev epoch is 9, loss is 12.968338012695312
# dev epoch is 10, loss is 12.833345413208008
# load model and print results...
# run is 10, aucroc is 0.466889
# run is 10, aucpr is 0.781733
# average AUC-ROC is 0.476421, average AUC-PR is 0.788216
# std AUC-ROC is 0.021933, std AUC-PR is 0.008980

# %%
plt.plot(pred)

# %%
y_ = np.zeros(984)
for i in range(984):
  y_[i] = np.mean(-pred[i*5:5*(i+1)])
y_scores = y_[0:984] # Predicted scores

# %%
# y_ = np.zeros(5)
# for i in range(5):
#   y_[i] = np.mean(pred[i*400:400*(i+1)])
# y_scores = y_ # Predicted scores

# %%
plt.plot(y_scores)

# %%
import scipy.io as scio
HI_t = y_
HI_t_ = pred
scio.savemat('AE_Diffusion/AE_data_ims/result_1000_IMS_FEAWAD(2).mat',{'HI_t':HI_t,'HI_t_':HI_t_})

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score, average_precision_score, confusion_matrix, matthews_corrcoef

# 假设 y_true 是真实标签，y_scores 是异常分数
# 二进制分类问题中，通常使用 1 表示正常样本，0 表示异常样本

# 示例数据
# y_true = [1, 0, 1, 1, 0, 1, 0, 0]
# y_scores = [0.8, 0.2, 0.6, 0.9, 0.3, 0.7, 0.1, 0.4]
y_true = np.concatenate((np.zeros(831),np.ones(119)))
y_pred = y_scores


# 阈值，用于将异常分数转换为二进制标签
mean_ocsv = np.mean(y_scores[0:200])
std_ocsv = np.std(y_scores[0:200])
threshold_ocsv = mean_ocsv + 6*std_ocsv
y_pred = [1 if score >= threshold_ocsv else 0 for score in y_scores]

# 计算精确度
precision = precision_score(y_true, y_pred)

# 计算召回率
recall = recall_score(y_true, y_pred)

# 计算F1分数
f1 = f1_score(y_true, y_pred)

# 计算ROC曲线下的面积（AUC）
roc_auc_ocsv = roc_auc_score(y_true, y_scores)

# 计算PR曲线下的面积（AP）
average_precision_ocsv = average_precision_score(y_true, y_scores)

# 计算混淆矩阵
conf_matrix = confusion_matrix(y_true, y_pred)

# 计算Matthews相关系数
mcc = matthews_corrcoef(y_true, y_pred)

# 输出结果
print("精确度：", precision)
print("召回率：", recall)
print("F1分数：", f1)
print("ROC曲线下的面积（AUC）：", roc_auc_ocsv)
print("PR曲线下的面积（AP）：", average_precision_ocsv)
print("混淆矩阵：\n", conf_matrix)
print("Matthews相关系数：", mcc)
# Out:
# 精确度： 1.0
# 召回率： 0.08403361344537816
# F1分数： 0.1550387596899225
# ROC曲线下的面积（AUC）： 0.7893294501916288
# PR曲线下的面积（AP）： 0.5908320242847249
# 混淆矩阵：
#  [[831   0]
#  [109  10]]
# Matthews相关系数： 0.2725606174489608

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import precision_recall_curve, roc_curve, auc

# Example data (replace with your actual data)
# y_true = [...]  # True labels
y_true = np.concatenate((np.zeros(831),np.ones(119)))


# Calculate precision-recall curve
precision, recall, _ = precision_recall_curve(y_true, y_scores)
auprc = auc(recall, precision)

# Calculate ROC curve
fpr, tpr, _ = roc_curve(y_true, y_scores)
auroc = auc(fpr, tpr)

# Plot AUPRC
plt.figure()
plt.plot(recall, precision, label='AUPRC = %0.2f' % auprc)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc='lower left')

# Plot AUROC
plt.figure()
plt.plot(fpr, tpr, label='AUROC = %0.2f' % auroc)
plt.plot([0, 1], [0, 1], linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic Curve')
plt.legend(loc='lower right')

plt.show()
